# %%
#Import the necessary packages

import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

plt.style.use('science') #https://github.com/garrettj403/SciencePlots

# %%
#Read the data from the .txt file as a 2d array

data = np.loadtxt('data.txt')

I_cs = data[:,0]
x_cs = data[:,1]

I_co1 = data[:,2]
x_co1 = data[:,3]

I_co2 = data[:,4]
x_co2 = data[:,5]

I_na = data[:,6]
x_na = data[:,7]

errors = x_na*0 #In order to use plt.errorbar()

# %%
#Define the fit function
def fit (x, a, b):
	return a * np.exp(-x*b)

x = np.linspace(1, 9, 1000)

# %%
popt, pcov = curve_fit(fit, x_cs, I_cs, p0=(1577, 1))
print("Cs-137 Fit results:")
print(popt)
print(np.sqrt(np.diag(pcov)))

plt.errorbar(x_cs, I_cs, errors, errors, 'bo')
plt.plot(x, fit(x, *popt), 'r--')
plt.grid()
plt.title('$I = f(\chi ), ^{137}Cs$')
#plt.ylabel('$I (counts/sec)$')
#plt.xlabel('$\chi ( gr/cm^2)$')
plt.ylabel('$I \dfrac{counts}{sec}$')
plt.xlabel('$\chi \dfrac{gr}{cm^2}$')
plt.legend(['Fit function', 'Experimental data'])
plt.savefig('I_cs.png', dpi=500)

plt.show()

plt.errorbar(x_cs, I_cs, errors, errors, 'bo')
plt.plot(x, fit(x, *popt), 'r--')
plt.grid()
plt.semilogy()
plt.title('$I = f(\chi ), ^{137}Cs$')
#plt.ylabel('$I (counts/sec)$')
#plt.xlabel('$\chi ( gr/cm^2)$')
plt.ylabel('$I \dfrac{counts}{sec}$')
plt.xlabel('$\chi \dfrac{gr}{cm^2}$')
plt.legend(['Fit function', 'Experimental data'])
plt.savefig('I_cs_log.png', dpi=500)
# Out:
# Cs-137 Fit results:
# [9.45358815e+02 1.01284525e-01]
# [3.49453757e+00 8.84332022e-04]

# %%
popt, pcov = curve_fit(fit, x_co1, I_co1, p0=(556, 1))
print("Co-60 - 1 Fit results:")
print(popt)
print(np.sqrt(np.diag(pcov)))

plt.errorbar(x_co1, I_co1, errors, errors, 'bo')
plt.plot(x, fit(x, *popt), 'r--')
plt.grid()
plt.title('$I = f(\chi ), ^{60}Co-1$')
#plt.ylabel('$I (counts/sec)$')
#plt.xlabel('$\chi ( gr/cm^2)$')
plt.ylabel('$I \dfrac{counts}{sec}$')
plt.xlabel('$\chi \dfrac{gr}{cm^2}$')
plt.legend(['Fit function', 'Experimental data'])
plt.savefig('I_co1.png', dpi=500)

plt.show()

plt.errorbar(x_co1, I_co1, errors, errors, 'bo')
plt.plot(x, fit(x, *popt), 'r--')
plt.grid()
plt.semilogy()
plt.title('$I = f(\chi ), ^{60}Co-1$')
#plt.ylabel('$I (counts/sec)$')
#plt.xlabel('$\chi ( gr/cm^2)$')
plt.ylabel('$I \dfrac{counts}{sec}$')
plt.xlabel('$\chi \dfrac{gr}{cm^2}$')
plt.legend(['Fit function', 'Experimental data'])
plt.savefig('I_co1_log.png', dpi=500)
# Out:
# Co-60 - 1 Fit results:
# [2.41741531e+02 4.96215682e-02]
# [4.76582921e+00 4.22734404e-03]

# %%
popt, pcov = curve_fit(fit, x_co2, I_co2, p0=(455, 1))
print("Co-60 - 2 Fit results:")
print(popt)
print(np.sqrt(np.diag(pcov)))

plt.errorbar(x_co2, I_co2, errors, errors, 'bo')
plt.plot(x, fit(x, *popt), 'r--')
plt.grid()
plt.title('$I = f(\chi ), ^{60}Co-2$')
#plt.ylabel('$I (counts/sec)$')
#plt.xlabel('$\chi ( gr/cm^2)$')
plt.ylabel('$I \dfrac{counts}{sec}$')
plt.xlabel('$\chi \dfrac{gr}{cm^2}$')
plt.legend(['Fit function', 'Experimental data'])
plt.savefig('I_co2.png', dpi=500)

plt.show()


plt.errorbar(x_co2, I_co2, errors, errors, 'bo')
plt.plot(x, fit(x, *popt), 'r--')
plt.grid()
plt.semilogy()
plt.title('$I = f(\chi ), ^{60}Co-2$')
#plt.ylabel('$I (counts/sec)$')
#plt.xlabel('$\chi ( gr/cm^2)$')
plt.ylabel('$I \dfrac{counts}{sec}$')
plt.xlabel('$\chi \dfrac{gr}{cm^2}$')
plt.legend(['Fit function', 'Experimental data'])
plt.savefig('I_co2_log.png', dpi=500)
# Out:
# Co-60 - 2 Fit results:
# [2.07490074e+02 5.36783543e-02]
# [1.72727607 0.0018003 ]

# %%
popt, pcov = curve_fit(fit, x_na, I_na, p0=(112, 1))
print("Na-22 Fit results:")
print(popt)
print(np.sqrt(np.diag(pcov)))

plt.errorbar(x_na, I_na, errors, errors, 'bo')
plt.plot(x, fit(x, *popt), 'r--')
plt.grid()
plt.title('$I = f(\chi ), ^{22}Na$')
plt.ylabel('$I \dfrac{counts}{sec}$')
plt.xlabel('$\chi \dfrac{gr}{cm^2}$')
plt.legend(['Fit function', 'Experimental data'])
plt.savefig('I_na.png', dpi=500)

plt.show()


plt.errorbar(x_na, I_na, errors, errors, 'bo')
plt.plot(x, fit(x, *popt), 'r--')
plt.grid()
plt.semilogy()
plt.title('$I = f(\chi ), ^{22}Na$')
plt.ylabel('$I \dfrac{counts}{sec}$')
plt.xlabel('$\chi \dfrac{gr}{cm^2}$')
plt.legend(['Fit function', 'Experimental data'])
plt.savefig('I_na.png', dpi=500)
# Out:
# Na-22 Fit results:
# [36.29451845  0.11868684]
# [0.62373688 0.00429176]
